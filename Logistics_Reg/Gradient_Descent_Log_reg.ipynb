# %% [markdown]
# ## SKLEARN LOGISTIC REGRESSION

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=100,random_state=41,n_classes=2,n_clusters_per_class=1,n_features=2,n_informative=1,n_redundant=0,hypercube=False,class_sep=20)

# %%
lor = LogisticRegression(penalty=None,solver='sag')

# %%
lor.fit(X,y)
# Out:
# c:\Users\Bharat Maheshwari\OneDrive\Desktop\Road to AI engineer\Machine Learning\Supervised_ML\.venv\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(penalty=None, solver='sag')

# %%
m = -(lor.coef_[0][0]/lor.coef_[0][1])
c = -(lor.intercept_/lor.coef_[0][1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + c

# %%
plt.plot(x_input,y_input,color = "black",linewidth = 3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter')
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %% [markdown]
# ## Using Gradient Descent from Scratch

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

def gd(X,y):
    X= np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.5

    for i in range(5000):
        y_hat = sigmoid(np.dot(X,weights))
        weights = weights + lr*(np.dot((y-y_hat),X)/X.shape[0])

    return weights[0],weights[1:]

# %%
intercept_ , coef_ = gd(X,y)

# %%
m = - (coef_[0]/coef_[1])
c = - (intercept_/coef_[1])

# %%
x_input1 = np.linspace(-3,3,100)
y_input1 = m*x_input1 + c

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=5)
plt.plot(x_input1,y_input1,color='black',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter')
plt.title("Gradient Descent vs Skicit Learn Native Logistics Reg(Overlapping)")
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
